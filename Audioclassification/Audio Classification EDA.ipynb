# %%
# !pip install librosa
# Out:
# Requirement already satisfied: librosa in c:\users\vutru\miniconda3\lib\site-packages (0.9.1)
# Requirement already satisfied: scipy>=1.2.0 in c:\users\vutru\miniconda3\lib\site-packages (from librosa) (1.7.3)
# Requirement already satisfied: scikit-learn>=0.19.1 in c:\users\vutru\miniconda3\lib\site-packages (from librosa) (1.0.2)
# Requirement already satisfied: joblib>=0.14 in c:\users\vutru\miniconda3\lib\site-packages (from librosa) (1.1.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\vutru\miniconda3\lib\site-packages (from librosa) (21.3)
# Requirement already satisfied: decorator>=4.0.10 in c:\users\vutru\miniconda3\lib\site-packages (from librosa) (5.1.1)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\vutru\miniconda3\lib\site-packages (from librosa) (1.21.5)
# Requirement already satisfied: numba>=0.45.1 in c:\users\vutru\miniconda3\lib\site-packages (from librosa) (0.55.1)
# Requirement already satisfied: audioread>=2.1.5 in c:\users\vutru\miniconda3\lib\site-packages (from librosa) (2.1.9)
# Requirement already satisfied: soundfile>=0.10.2 in c:\users\vutru\miniconda3\lib\site-packages (from librosa) (0.10.3.post1)
# Requirement already satisfied: pooch>=1.0 in c:\users\vutru\miniconda3\lib\site-packages (from librosa) (1.6.0)
# Requirement already satisfied: resampy>=0.2.2 in c:\users\vutru\miniconda3\lib\site-packages (from librosa) (0.2.2)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in c:\users\vutru\miniconda3\lib\site-packages (from numba>=0.45.1->librosa) (0.38.0)
# Requirement already satisfied: setuptools in c:\users\vutru\miniconda3\lib\site-packages (from numba>=0.45.1->librosa) (58.0.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\vutru\miniconda3\lib\site-packages (from packaging>=20.0->librosa) (3.0.4)
# Requirement already satisfied: appdirs>=1.3.0 in c:\users\vutru\miniconda3\lib\site-packages (from pooch>=1.0->librosa) (1.4.4)
# Requirement already satisfied: requests>=2.19.0 in c:\users\vutru\miniconda3\lib\site-packages (from pooch>=1.0->librosa) (2.25.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\vutru\miniconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2020.6.20)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\vutru\miniconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (1.26.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\vutru\miniconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\vutru\miniconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2.10)
# Requirement already satisfied: six>=1.3 in c:\users\vutru\miniconda3\lib\site-packages (from resampy>=0.2.2->librosa) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\vutru\miniconda3\lib\site-packages (from scikit-learn>=0.19.1->librosa) (2.2.0)
# Requirement already satisfied: cffi>=1.0 in c:\users\vutru\miniconda3\lib\site-packages (from soundfile>=0.10.2->librosa) (1.15.0)
# Requirement already satisfied: pycparser in c:\users\vutru\miniconda3\lib\site-packages (from cffi>=1.0->soundfile>=0.10.2->librosa) (2.21)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# !pip3 install ipython==7.23.1
# Out:
# Collecting ipython==7.23.1
#   Using cached ipython-7.23.1-py3-none-any.whl (785 kB)
# Requirement already satisfied: jedi>=0.16 in c:\users\vutru\miniconda3\lib\site-packages (from ipython==7.23.1) (0.18.1)
# Requirement already satisfied: setuptools>=18.5 in c:\users\vutru\miniconda3\lib\site-packages (from ipython==7.23.1) (58.0.4)
# Requirement already satisfied: pickleshare in c:\users\vutru\miniconda3\lib\site-packages (from ipython==7.23.1) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\vutru\miniconda3\lib\site-packages (from ipython==7.23.1) (3.0.28)
# Requirement already satisfied: traitlets>=4.2 in c:\users\vutru\miniconda3\lib\site-packages (from ipython==7.23.1) (5.1.1)
# Requirement already satisfied: backcall in c:\users\vutru\miniconda3\lib\site-packages (from ipython==7.23.1) (0.2.0)
# Requirement already satisfied: pygments in c:\users\vutru\miniconda3\lib\site-packages (from ipython==7.23.1) (2.11.2)
# Requirement already satisfied: decorator in c:\users\vutru\miniconda3\lib\site-packages (from ipython==7.23.1) (5.1.1)
# Requirement already satisfied: colorama in c:\users\vutru\miniconda3\lib\site-packages (from ipython==7.23.1) (0.4.4)
# Requirement already satisfied: matplotlib-inline in c:\users\vutru\miniconda3\lib\site-packages (from ipython==7.23.1) (0.1.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\vutru\miniconda3\lib\site-packages (from jedi>=0.16->ipython==7.23.1) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\vutru\miniconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython==7.23.1) (0.2.5)
# Installing collected packages: ipython
#   Attempting uninstall: ipython
#     Found existing installation: ipython 8.2.0
#     Uninstalling ipython-8.2.0:
#       Successfully uninstalled ipython-8.2.0
# Successfully installed ipython-7.23.1

# %%
# !pip3 install --upgrade IPython
# Out:
# Requirement already satisfied: IPython in c:\users\vutru\miniconda3\lib\site-packages (7.23.1)
# Collecting IPython
#   Using cached ipython-8.2.0-py3-none-any.whl (750 kB)
# Requirement already satisfied: pickleshare in c:\users\vutru\miniconda3\lib\site-packages (from IPython) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in c:\users\vutru\miniconda3\lib\site-packages (from IPython) (0.18.1)
# Requirement already satisfied: colorama in c:\users\vutru\miniconda3\lib\site-packages (from IPython) (0.4.4)
# Requirement already satisfied: decorator in c:\users\vutru\miniconda3\lib\site-packages (from IPython) (5.1.1)
# Requirement already satisfied: setuptools>=18.5 in c:\users\vutru\miniconda3\lib\site-packages (from IPython) (58.0.4)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\vutru\miniconda3\lib\site-packages (from IPython) (3.0.28)
# Requirement already satisfied: traitlets>=5 in c:\users\vutru\miniconda3\lib\site-packages (from IPython) (5.1.1)
# Requirement already satisfied: stack-data in c:\users\vutru\miniconda3\lib\site-packages (from IPython) (0.2.0)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\vutru\miniconda3\lib\site-packages (from IPython) (2.11.2)
# Requirement already satisfied: backcall in c:\users\vutru\miniconda3\lib\site-packages (from IPython) (0.2.0)
# Requirement already satisfied: matplotlib-inline in c:\users\vutru\miniconda3\lib\site-packages (from IPython) (0.1.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\vutru\miniconda3\lib\site-packages (from jedi>=0.16->IPython) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\vutru\miniconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython) (0.2.5)
# Requirement already satisfied: executing in c:\users\vutru\miniconda3\lib\site-packages (from stack-data->IPython) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\vutru\miniconda3\lib\site-packages (from stack-data->IPython) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\vutru\miniconda3\lib\site-packages (from stack-data->IPython) (0.2.2)
# Requirement already satisfied: six in c:\users\vutru\miniconda3\lib\site-packages (from asttokens->stack-data->IPython) (1.16.0)
# Installing collected packages: IPython
#   Attempting uninstall: IPython
#     Found existing installation: ipython 7.23.1
#     Uninstalling ipython-7.23.1:
#       Successfully uninstalled ipython-7.23.1
# Successfully installed IPython-8.2.0

# %%
import IPython.display as ipd
import librosa
import librosa.display

# %%
pwd
# Out:
# 'E:\\Audioclassification'

# %%
ls
# Out:
#  Volume in drive E is Other
#  Volume Serial Number is D6E2-8A07
#
#  Directory of E:\Audioclassification
#
# 04/04/2022  04:13 PM    <DIR>          .
# 04/04/2022  04:13 PM    <DIR>          ..
# 04/04/2022  01:16 PM    <DIR>          .ipynb_checkpoints
# 04/04/2022  04:13 PM           367,260 Audio Classification EDA.ipynb
# 04/04/2022  03:04 PM    <DIR>          UrbanSound8K
#                1 File(s)        367,260 bytes
#                4 Dir(s)  15,866,425,344 bytes free

# %%
# !dir
# Out:
#  Volume in drive E is Other
#  Volume Serial Number is D6E2-8A07
#
#  Directory of E:\Audioclassification
#
# 04/04/2022  04:13 PM    <DIR>          .
# 04/04/2022  04:13 PM    <DIR>          ..
# 04/04/2022  01:16 PM    <DIR>          .ipynb_checkpoints
# 04/04/2022  04:13 PM           367,260 Audio Classification EDA.ipynb
# 04/04/2022  03:04 PM    <DIR>          UrbanSound8K
#                1 File(s)        367,260 bytes
#                4 Dir(s)  15,866,425,344 bytes free

# %%
filename = "UrbanSound8K/dog_bark.wav"

# %%
import librosa
import librosa.display
plt.figure(figsize=(14, 5))
data,sampling_rate =librosa.load(filename)
librosa.display.waveshow(data,sr=sampling_rate)
#librosa.display.waveplot(data, sr=sample_rate)
#Audio: load audio that is in the formm of wavefile
ipd.Audio(filename)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
sampling_rate
# Out:
# 22050

# %%
# !pip install scipy
# Out:
# Requirement already satisfied: scipy in c:\users\vutru\miniconda3\lib\site-packages (1.7.3)
# Requirement already satisfied: numpy<1.23.0,>=1.16.5 in c:\users\vutru\miniconda3\lib\site-packages (from scipy) (1.21.5)

# %%
import scipy

# %%
scipy.__version__
# Out:
# '1.7.3'

# %%
import numpy as np

# %%
import scipy.io
from scipy.io import wavfile as wav
wave_sample_rate, wave_audio = wav.read(filename)

# %%
wave_sample_rate
# Out:
# 44100

# %%
 wave_audio
# Out:
# array([[ 14,   2],
#        [ 18,  10],
#        [ 17,  13],
#        ...,
#        [110,  69],
#        [118,  63],
#        [123,  51]], dtype=int16)

# %%
wave_audio.shape
# Out:
# (60417, 2)

# %%
data
# Out:
# array([0.00022974, 0.00047337, 0.00050239, ..., 0.00270325, 0.00296801,
#        0.        ], dtype=float32)

# %%
import pandas as pd
metadata = pd.read_csv('UrbanSound8K/metadata/UrbanSound8K.csv')
metadata.head(10)
# Out:
#       slice_file_name    fsID      start        end  salience  fold  classID  \
# 0    100032-3-0-0.wav  100032   0.000000   0.317551         1     5        3
# 1  100263-2-0-117.wav  100263  58.500000  62.500000         1     5        2
# 2  100263-2-0-121.wav  100263  60.500000  64.500000         1     5        2
# 3  100263-2-0-126.wav  100263  63.000000  67.000000         1     5        2
# 4  100263-2-0-137.wav  100263  68.500000  72.500000         1     5        2
# 5  100263-2-0-143.wav  100263  71.500000  75.500000         1     5        2
# 6  100263-2-0-161.wav  100263  80.500000  84.500000         1     5        2
# 7    100263-2-0-3.wav  100263   1.500000   5.500000         1     5        2
# 8   100263-2-0-36.wav  100263  18.000000  22.000000         1     5        2
# 9    100648-1-0-0.wav  100648   4.823402   5.471927         2    10        1
#
#               class
# 0          dog_bark
# 1  children_playing
# 2  children_playing
# 3  children_playing
# 4  children_playing
# 5  children_playing
# 6  children_playing
# 7  children_playing
# 8  children_playing
# 9          car_horn

# %%
### Check whether the dataset is imbalanced
metadata['class'].value_counts()
# Out:
# air_conditioner     1000
# children_playing    1000
# street_music        1000
# jackhammer          1000
# engine_idling       1000
# drilling            1000
# dog_bark            1000
# siren                929
# car_horn             429
# gun_shot             374
# Name: class, dtype: int64
